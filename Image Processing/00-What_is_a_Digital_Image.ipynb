# %% [markdown]
# ## Digital Image

# %% [markdown]
# A digital image is an image composed of picture elements, also known as pixels, each with finite, discrete quantities of numeric representation for its intensity or gray level that is an output from its two-dimensional functions fed as input by its spatial coordinates denoted with x, y on the x-axis and y-axis, respectively. Depending on whether the image resolution is fixed, it may be of vector or raster type.

# %% [markdown]
# # Common Image Formats
# Common image formats include: PPM, PNG, JPEG, GIF, TIFF, and BMP.
#
# ## Gray Image
# - Monochrome (gray) images represent the brightness of each pixel with a numerical value.
# - Typically, this value ranges from 0 to 255, where 0 denotes black, 255 indicates white, and values in between represent shades of gray.
#
# ## Color Image
# - Color images are represented by two-dimensional matrices of Red, Green, and Blue (RGB) triplets.
#   - Are you familiar with RGB?
# - Each value in an RGB triplet usually falls between 0 and 255:
#   - A value of 0 signifies that the corresponding primary color is absent in the pixel.
#   - A value of 255 indicates that the primary color is fully present in the pixel.

# %% [markdown]
# ## Example Digit Image: tyrion_lannister.jpg
# ![alt text](image/axis_tyrion_lannister.jpg)
#
#
#
# Pixel representation of digital images
#
# What is a pixel?
#
# Digital images are composed of two-dimensional elements, each of which has a specific position (x, y) and amplitude f(x, y). These elements are called pixels.

# %%
# 
from PIL import Image  
from numpy  import *
import matplotlib.pyplot as plt

# The image filename is lady_gray.jpg

img=Image.open('./image/tyrion_lannister.jpg')

# 
plt.imshow(img)
plt.show()

# 
img.size
# Out:
# (869, 577)
