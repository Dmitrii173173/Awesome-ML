# %%
from PIL import Image  
import matplotlib.pyplot as plt
img=Image.open('./image/tyrion_lannister.jpg')

plt.imshow(img)
plt.show()

# %%
import matplotlib
import matplotlib.pyplot as plt

img=Image.open('./image/tyrion_lannister.jpg')

## New name: street-sign-save.jpg
img.save('tyrion_lannister.jpg')

## Tip: 
## When you finish these steps, you will find a new file called street-sign-save.jpg in your left column.

## Or, we can open it now.
img=Image.open('./tyrion_lannister.jpg')
plt.imshow(img)
plt.show()

# %% [markdown]
# ## Transformation

# %%
from PIL import Image  
import matplotlib.pyplot as plt

## 
img=Image.open('./tyrion_lannister.jpg')

## 
region = (100,100,700,450)
cropImg = img.crop(region)

## 
plt.imshow(cropImg)
plt.show()
