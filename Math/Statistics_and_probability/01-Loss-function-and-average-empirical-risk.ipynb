# %% [markdown]
# ## Loss function and average empirical risk

# %%
from IPython.display import Markdown, display

def display_markdown_with_latex(text):
    display(Markdown(text))

text = """
* **Training Dataset:**
    
    * **Definition:** A training dataset, also known as a training set or training data, refers to a collection of examples used to fit a machine learning model. It consists of input data samples along with their corresponding target labels or outputs.
    * **Formula:** Let $D_{\text{train}} = \{(x^{(1)}, y^{(1)}), (x^{(2)}, y^{(2)}), \ldots, (x^{(m)}, y^{(m)})\}$ be a training dataset, where $x^{(i)}$ represents the $i^{th}$ input sample and $y^{(i)}$ represents the corresponding target label. Here, $m$ denotes the number of examples in the dataset.
    
* **Feature Space:**
    
    * **Definition:** Feature space, also known as input space or attribute space, refers to the space formed by the various features or attributes of the input data. Each dimension in the feature space corresponds to a specific feature, and each data point is represented as a vector in this space.
    * **Formula:** Let $X = \{x_1, x_2, \ldots, x_n\}$ represent the set of features, where $n$ is the number of features. For a given input sample $x^{(i)} = (x^{(i)}_1, x^{(i)}_2, \ldots, x^{(i)}_n)$, where $x_j^{(i)}$ denotes the value of the $j^{th}$ feature for the $i^{th}$ sample. The feature space is denoted by $\mathbb{R}^n$, indicating that each sample is represented as an $n$-dimensional vector in the real number space.
"""

display_markdown_with_latex(text)
# Out:
# * **Training Dataset:**
#
#     * **Definition:** A training dataset, also known as a training set or training data, refers to a collection of examples used to fit a machine learning model. It consists of input data samples along with their corresponding target labels or outputs.
#     * **Formula:** Let $D_{	ext{train}} = \{(x^{(1)}, y^{(1)}), (x^{(2)}, y^{(2)}), \ldots, (x^{(m)}, y^{(m)})\}$ be a training dataset, where $x^{(i)}$ represents the $i^{th}$ input sample and $y^{(i)}$ represents the corresponding target label. Here, $m$ denotes the number of examples in the dataset.
#
# * **Feature Space:**
#
#     * **Definition:** Feature space, also known as input space or attribute space, refers to the space formed by the various features or attributes of the input data. Each dimension in the feature space corresponds to a specific feature, and each data point is represented as a vector in this space.
# ...

# %% [markdown]
# ![image.png](attachment:image.png)
#
# ![image-2.png](attachment:image-2.png)
#
# ![image-3.png](attachment:image-3.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression

np.random.seed(0)
X = 3 * np.random.rand(100, 1)
y = 8 + 4 * X + np.random.randn(100, 1)

model = LinearRegression()
model.fit(X, y)

plt.figure(figsize=(10, 6))
plt.scatter(X, y, color='blue', label='Training data')
plt.plot(X, model.predict(X), color='red', label='Linear regression')
plt.title('Linear Regression')
plt.xlabel('X')
plt.ylabel('y')
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# ![image.png](attachment:image.png)
#
# LOSS FUNCTION - функция потерь

# %% [markdown]
# ![image.png](attachment:image.png)
#
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# ![image.png](attachment:image.png)
#
# метод наименьших квадратов МНК

# %% [markdown]
# ![image.png](attachment:image.png)
